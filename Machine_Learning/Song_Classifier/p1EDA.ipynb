# %%
import pandas as pd
import seaborn as sns  
import matplotlib.pyplot as plt
import numpy as np

dane = pd.read_csv("dane/Spotify_Youtube.csv")
dane.head()
# Out:
#    Unnamed: 0    Artist                                        Url_spotify  \
# 0           0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1           1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2           2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3           3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4           4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                            Track  \
# 0                                 Feel Good Inc.
# 1                                Rhinestone Eyes
# 2  New Gold (feat. Tame Impala and Bootie Brown)
# 3                             On Melancholy Hill
# 4                                 Clint Eastwood
#
#                                            Album Album_type  \
# 0                                     Demon Days      album
# 1                                  Plastic Beach      album
# ...

# %%
#Track: name of the song, as visible on the Spotify platform.

#Artist: name of the artist.

#Url_spotify: the Url of the artist.

#Album: the album in wich the song is contained on Spotify.

#Album_type: indicates if the song is relesead on Spotify as a single or contained in an album.

#Uri: a spotify link used to find the song through the API.

#Danceability: describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable.

#Energy: is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy. For example, death metal has high energy, while a Bach prelude scores low on the scale. Perceptual features contributing to this attribute include dynamic range, perceived loudness, timbre, onset rate, and general entropy.

#Key: the key the track is in. Integers map to pitches using standard Pitch Class notation. E.g. 0 = C, 1 = C♯/D♭, 2 = D, and so on. If no key was detected, the value is -1.

#Loudness: the overall loudness of a track in decibels (dB). Loudness values are averaged across the entire track and are useful for comparing relative loudness of tracks. Loudness is the quality of a sound that is the primary psychological correlate of physical strength (amplitude). Values typically range between -60 and 0 db.

#Speechiness: detects the presence of spoken words in a track. The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), the closer to 1.0 the attribute value. Values above 0.66 describe tracks that are probably made entirely of spoken words. Values between 0.33 and 0.66 describe tracks that may contain both music and speech, either in sections or layered, including such cases as rap music. Values below 0.33 most likely represent music and other non-speech-like tracks.

#Acousticness: a confidence measure from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents high confidence the track is acoustic.

#Instrumentalness: predicts whether a track contains no vocals. "Ooh" and "aah" sounds are treated as instrumental in this context. Rap or spoken word tracks are clearly "vocal". The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content. Values above 0.5 are intended to represent instrumental tracks, but confidence is higher as the value approaches 1.0.

#Liveness: detects the presence of an audience in the recording. Higher liveness values represent an increased probability that the track was performed live. A value above 0.8 provides strong likelihood that the track is live.

#Valence: a measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry).

#Tempo: the overall estimated tempo of a track in beats per minute (BPM). In musical terminology, tempo is the speed or pace of a given piece and derives directly from the average beat duration.

#Duration_ms: the duration of the track in milliseconds.

#Stream: number of streams of the song on Spotify.

#Url_youtube: url of the video linked to the song on Youtube, if it have any.

#Title: title of the videoclip on youtube.

#Channel: name of the channel that have published the video.

#Views: number of views.

#Likes: number of likes.

#Comments: number of comments.

#Description: description of the video on Youtube.

#Licensed: Indicates whether the video represents licensed content, which means that the content was uploaded to a channel linked to a YouTube content partner and then claimed by that partner.

#official_video: boolean value that indicates if the video found is the official video of the song.

# %%
dane_speech = dane.sort_values(by="Speechiness", ascending=False)

dane_speech.head(120)
# Out:
#        Unnamed: 0                  Artist  \
# 5158         5158  Sir Arthur Conan Doyle
# 5152         5152  Sir Arthur Conan Doyle
# 996           996         Bibi Blocksberg
# 994           994         Bibi Blocksberg
# 13418       13418         Sherlock Holmes
# ...           ...                     ...
# 5900         5900        Santiago Ziesmer
# 478           478            Die drei ???
# 12324       12324           Teufelskicker
# 11936       11936                  D.O.E.
# 12318       12318           Teufelskicker
#
#                                              Url_spotify  \
# 5158   https://open.spotify.com/artist/3Xj8xqJUruJ2mo...
# 5152   https://open.spotify.com/artist/3Xj8xqJUruJ2mo...
# 996    https://open.spotify.com/artist/3t2iKODSDyzoDJ...
# 994    https://open.spotify.com/artist/3t2iKODSDyzoDJ...
# 13418  https://open.spotify.com/artist/2YlvvdXUqRjiXm...
# ...                                                  ...
# ...

# %%
dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20718 entries, 0 to 20717
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        20718 non-null  int64
#  1   Artist            20718 non-null  object
#  2   Url_spotify       20718 non-null  object
#  3   Track             20718 non-null  object
#  4   Album             20718 non-null  object
#  5   Album_type        20718 non-null  object
#  6   Uri               20718 non-null  object
#  7   Danceability      20716 non-null  float64
#  8   Energy            20716 non-null  float64
#  9   Key               20716 non-null  float64
#  10  Loudness          20716 non-null  float64
#  11  Speechiness       20716 non-null  float64
#  12  Acousticness      20716 non-null  float64
#  13  Instrumentalness  20716 non-null  float64
#  14  Liveness          20716 non-null  float64
#  15  Valence           20716 non-null  float64
# ...

# %%
dane.columns = dane.columns.str.strip() 


dane = dane[["Danceability","Energy",  "Key", "Loudness", "Speechiness", 
         "Acousticness", "Instrumentalness", "Liveness", "Valence", "Tempo", 
         "Duration_ms", "Stream", "Views", "Likes", "Comments"]]

dane
# Out:
#        Danceability  Energy   Key  Loudness  Speechiness  Acousticness  \
# 0             0.818   0.705   6.0    -6.679       0.1770      0.008360
# 1             0.676   0.703   8.0    -5.815       0.0302      0.086900
# 2             0.695   0.923   1.0    -3.930       0.0522      0.042500
# 3             0.689   0.739   2.0    -5.810       0.0260      0.000015
# 4             0.663   0.694  10.0    -8.627       0.1710      0.025300
# ...             ...     ...   ...       ...          ...           ...
# 20713         0.582   0.926   5.0    -6.344       0.0328      0.448000
# 20714         0.531   0.936   4.0    -1.786       0.1370      0.028000
# 20715         0.443   0.830   4.0    -4.679       0.0647      0.024300
# 20716         0.417   0.767   9.0    -4.004       0.4190      0.356000
# 20717         0.498   0.938   6.0    -4.543       0.1070      0.002770
#
#        Instrumentalness  Liveness  Valence    Tempo  Duration_ms  \
# ...

# %%
dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20718 entries, 0 to 20717
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Danceability      20716 non-null  float64
#  1   Energy            20716 non-null  float64
#  2   Key               20716 non-null  float64
#  3   Loudness          20716 non-null  float64
#  4   Speechiness       20716 non-null  float64
#  5   Acousticness      20716 non-null  float64
#  6   Instrumentalness  20716 non-null  float64
#  7   Liveness          20716 non-null  float64
#  8   Valence           20716 non-null  float64
#  9   Tempo             20716 non-null  float64
#  10  Duration_ms       20716 non-null  float64
#  11  Stream            20142 non-null  float64
#  12  Views             20248 non-null  float64
#  13  Likes             20177 non-null  float64
#  14  Comments          20149 non-null  float64
# dtypes: float64(15)
# memory usage: 2.4 MB

# %%
dane.isnull().sum()
# Out:
# Danceability          2
# Energy                2
# Key                   2
# Loudness              2
# Speechiness           2
# Acousticness          2
# Instrumentalness      2
# Liveness              2
# Valence               2
# Tempo                 2
# Duration_ms           2
# Stream              576
# Views               470
# Likes               541
# Comments            569
# dtype: int64

# %%
dane["Danceability"] = dane["Danceability"].fillna(dane["Danceability"].mean()) 
dane["Energy"] = dane["Energy"].fillna(dane["Energy"].median())
dane["Key"] = dane["Key"].fillna(dane["Key"].median())
dane["Loudness"] = dane["Loudness"].fillna(dane["Loudness"].median())
dane["Speechiness"] = dane["Speechiness"].fillna(dane["Speechiness"].median())
dane["Acousticness"] = dane["Acousticness"].fillna(dane["Acousticness"].mean())
dane["Instrumentalness"] = dane["Instrumentalness"].fillna(dane["Instrumentalness"].median())
dane["Liveness"] = dane["Liveness"].fillna(dane["Liveness"].mean())
dane["Valence"] = dane["Valence"].fillna(dane["Valence"].mean())
dane["Tempo"] = dane["Tempo"].fillna(dane["Tempo"].mean())
dane["Duration_ms"] = dane["Duration_ms"].fillna(dane["Duration_ms"].median())
dane["Stream"] = dane["Stream"].fillna(dane["Stream"].mean())
dane["Views"] = dane["Views"].fillna(dane["Views"].mean())
dane["Likes"] = dane["Likes"].fillna(dane["Likes"].mean())
dane["Comments"] = dane["Comments"].fillna(dane["Comments"].mean())

# %%
dane.describe()
# Out:
#        Danceability        Energy           Key      Loudness   Speechiness  \
# count  20718.000000  20718.000000  20718.000000  20718.000000  20718.000000
# mean       0.619777      0.635253      5.300319     -7.671571      0.096452
# std        0.165264      0.214137      3.576277      4.632538      0.111956
# min        0.000000      0.000020      0.000000    -46.251000      0.000000
# 25%        0.518250      0.507000      2.000000     -8.858000      0.035700
# 50%        0.637000      0.666000      5.000000     -6.536000      0.050500
# 75%        0.740000      0.798000      8.000000     -4.931250      0.103000
# max        0.975000      1.000000     11.000000      0.920000      0.964000
#
#        Acousticness  Instrumentalness      Liveness       Valence  \
# count  20718.000000      20718.000000  20718.000000  20718.000000
# mean       0.291535          0.055956      0.193521      0.529853
# std        0.286285          0.193253      0.168523      0.245429
# ...

# %%
dane_clean = dane 

correlation_matrix = dane_clean.corr()  

sns.heatmap(correlation_matrix, annot=False, cmap="coolwarm")  
plt.show()

# %%
dane_clean["Views"] = dane_clean["Views"] + dane_clean["Stream"]
dane_clean = dane_clean.drop(columns=["Stream"])

print(dane_clean.head())
# Out:
#    Danceability  Energy   Key  Loudness  Speechiness  Acousticness  \
# 0         0.818   0.705   6.0    -6.679       0.1770      0.008360
# 1         0.676   0.703   8.0    -5.815       0.0302      0.086900
# 2         0.695   0.923   1.0    -3.930       0.0522      0.042500
# 3         0.689   0.739   2.0    -5.810       0.0260      0.000015
# 4         0.663   0.694  10.0    -8.627       0.1710      0.025300
#
#    Instrumentalness  Liveness  Valence    Tempo  Duration_ms         Views  \
# 0          0.002330    0.6130    0.772  138.559     222640.0  1.733790e+09
# 1          0.000687    0.0463    0.852   92.761     200173.0  3.820954e+08
# 2          0.046900    0.1160    0.551  108.014     215150.0  7.149852e+07
# 3          0.509000    0.0640    0.578  120.423     233867.0  6.464185e+08
# 4          0.000000    0.0698    0.525  167.953     340920.0  1.235741e+09
#
#        Likes  Comments
# 0  6220896.0  169907.0
# 1  1079128.0   31003.0
# 2   282142.0    7399.0
# ...

# %%
dane_clean.describe()
# Out:
#        Danceability        Energy           Key      Loudness   Speechiness  \
# count  20718.000000  20718.000000  20718.000000  20718.000000  20718.000000
# mean       0.619777      0.635253      5.300319     -7.671571      0.096452
# std        0.165264      0.214137      3.576277      4.632538      0.111956
# min        0.000000      0.000020      0.000000    -46.251000      0.000000
# 25%        0.518250      0.507000      2.000000     -8.858000      0.035700
# 50%        0.637000      0.666000      5.000000     -6.536000      0.050500
# 75%        0.740000      0.798000      8.000000     -4.931250      0.103000
# max        0.975000      1.000000     11.000000      0.920000      0.964000
#
#        Acousticness  Instrumentalness      Liveness       Valence  \
# count  20718.000000      20718.000000  20718.000000  20718.000000
# mean       0.291535          0.055956      0.193521      0.529853
# std        0.286285          0.193253      0.168523      0.245429
# ...

# %%
dane_clean.hist(bins = 50, figsize=(18, 12))
plt.show()

# %%
dane_log = dane_clean.copy()


cols_to_transform = ["Acousticness", "Instrumentalness", "Liveness", "Duration_ms", "Views", "Likes", "Comments"]


dane_log[cols_to_transform] = dane_log[cols_to_transform].apply(np.log1p)

dane_log.hist(bins = 50, figsize=(18, 12))

plt.show()

# %%
sns.pairplot(dane_log, 
             y_vars="Views", 
             x_vars=dane_clean.columns.values[:5], 
             kind="reg", 
             plot_kws={"scatter_kws": {"alpha": 0.5}, "line_kws": {"color": "red"}})

sns.pairplot(dane_log, 
             y_vars="Views", 
             x_vars=dane_clean.columns.values[5:10], 
             kind="reg", 
             plot_kws={"scatter_kws": {"alpha": 0.5}, "line_kws": {"color": "blue"}})

sns.pairplot(dane_log, 
             y_vars="Views", 
             x_vars=dane_clean.columns.values[10:], 
             kind="reg", 
             plot_kws={"scatter_kws": {"alpha": 0.5}, "line_kws": {"color": "green"}})

plt.show()
# Out:
# C:\Users\macie\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
dane_log.head()
# Out:
#    Danceability  Energy   Key  Loudness  Speechiness  Acousticness  \
# 0         0.818   0.705   6.0    -6.679       0.1770      0.008325
# 1         0.676   0.703   8.0    -5.815       0.0302      0.083330
# 2         0.695   0.923   1.0    -3.930       0.0522      0.041622
# 3         0.689   0.739   2.0    -5.810       0.0260      0.000015
# 4         0.663   0.694  10.0    -8.627       0.1710      0.024985
#
#    Instrumentalness  Liveness  Valence    Tempo  Duration_ms      Views  \
# 0          0.002327  0.478096    0.772  138.559    12.313316  21.273576
# 1          0.000687  0.045260    0.852   92.761    12.206942  19.761181
# 2          0.045833  0.109751    0.551  108.014    12.279095  18.085187
# 3          0.411447  0.062035    0.578  120.423    12.362512  20.286958
# 4          0.000000  0.067472    0.525  167.953    12.739406  20.934936
#
#        Likes   Comments
# 0  15.643425  12.043012
# 1  13.891665  10.341872
# 2  12.550169   8.909235
# 3  14.396931  10.919262
# ...

# %%
sns.pairplot(dane_log[["Likes", "Views", "Comments"]], 
             kind="reg", 
             plot_kws={"scatter_kws": {"alpha": 0.5}, "line_kws": {"color": "red"}})

plt.show()
# Out:
# C:\Users\macie\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\macie\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\macie\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
dane_log = dane_log.drop(columns=["Key", "Likes", "Comments"])
dane_log.head()
# Out:
#    Danceability  Energy  Loudness  Speechiness  Acousticness  \
# 0         0.818   0.705    -6.679       0.1770      0.008325
# 1         0.676   0.703    -5.815       0.0302      0.083330
# 2         0.695   0.923    -3.930       0.0522      0.041622
# 3         0.689   0.739    -5.810       0.0260      0.000015
# 4         0.663   0.694    -8.627       0.1710      0.024985
#
#    Instrumentalness  Liveness  Valence    Tempo  Duration_ms      Views
# 0          0.002327  0.478096    0.772  138.559    12.313316  21.273576
# 1          0.000687  0.045260    0.852   92.761    12.206942  19.761181
# 2          0.045833  0.109751    0.551  108.014    12.279095  18.085187
# 3          0.411447  0.062035    0.578  120.423    12.362512  20.286958
# 4          0.000000  0.067472    0.525  167.953    12.739406  20.934936

# %%
dane_log.hist(bins = 50, figsize=(18, 12))

plt.show()

# %%
sns.pairplot(dane_log, 
             y_vars="Views", 
             x_vars=dane_log.columns.values[:4], 
             kind="reg", 
             plot_kws={"scatter_kws": {"alpha": 0.5}, "line_kws": {"color": "red"}})

sns.pairplot(dane_log, 
             y_vars="Views", 
             x_vars=dane_log.columns.values[4:8], 
             kind="reg", 
             plot_kws={"scatter_kws": {"alpha": 0.5}, "line_kws": {"color": "blue"}})

sns.pairplot(dane_log, 
             y_vars="Views", 
             x_vars=dane_log.columns.values[8:], 
             kind="reg", 
             plot_kws={"scatter_kws": {"alpha": 0.5}, "line_kws": {"color": "green"}})

plt.show()
# Out:
# C:\Users\macie\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(5, 5))  # Dostosowanie rozmiaru dla jednej zmiennej
sns.boxplot(y=dane_log["Speechiness"])
plt.show()

# %%
percentyl_90 = dane_log["Speechiness"].quantile(0.90)

dane_log_cleaned = dane_log[dane_log["Speechiness"] <= percentyl_90]

plt.figure(figsize=(5, 5))
sns.boxplot(y=dane_log_cleaned["Speechiness"])
plt.show()

# %%
df = dane_log_cleaned.copy()

df.head()
# Out:
#    Danceability  Energy  Loudness  Speechiness  Acousticness  \
# 0         0.818   0.705    -6.679       0.1770      0.008325
# 1         0.676   0.703    -5.815       0.0302      0.083330
# 2         0.695   0.923    -3.930       0.0522      0.041622
# 3         0.689   0.739    -5.810       0.0260      0.000015
# 4         0.663   0.694    -8.627       0.1710      0.024985
#
#    Instrumentalness  Liveness  Valence    Tempo  Duration_ms      Views
# 0          0.002327  0.478096    0.772  138.559    12.313316  21.273576
# 1          0.000687  0.045260    0.852   92.761    12.206942  19.761181
# 2          0.045833  0.109751    0.551  108.014    12.279095  18.085187
# 3          0.411447  0.062035    0.578  120.423    12.362512  20.286958
# 4          0.000000  0.067472    0.525  167.953    12.739406  20.934936

# %%
    #KONIEC PREZENTACJI

# %%
#jakie cechy muzyczne wpływają na popularność utworów?


# my ucinamy bo interesuje nas czy piosenka będzie popularna. Dlatego nie interesuje nas czy ma milion czy miliard bo to i tak duzo

# %%
#czyli warto usunac stream

# %%
# !pip install xgboost
# Out:
# ...
#   Using cached xgboost-3.0.0-py3-none-win_amd64.whl.metadata (2.1 kB)
# ...
# Using cached xgboost-3.0.0-py3-none-win_amd64.whl (150.0 MB)
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

percentiles = np.percentile(df["Views"], [0, 20, 40, 60, 80, 100])
bins = list(percentiles)
labels = [0, 1, 2, 3, 4]
df['popularity_class'] = pd.cut(df['Views'], bins=bins, labels=labels, include_lowest=True)

X = df.drop(columns=["Views", "popularity_class"])
y = df["popularity_class"].astype(int)

test_size = 0.2
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=42)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

rf_classifier = RandomForestClassifier(n_estimators=100, max_depth=15, random_state=42)
rf_classifier.fit(X_train_scaled, y_train)
y_pred_rf = rf_classifier.predict(X_test_scaled)

print("Random Forest Classifier:")
print("Accuracy:", accuracy_score(y_test, y_pred_rf))
print(classification_report(y_test, y_pred_rf))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_rf))

xgb_classifier = XGBClassifier(n_estimators=100, max_depth=6, learning=0.1, use_label_encoder=False, eval_metric='mlogloss', random_state=42)
xgb_classifier.fit(X_train_scaled, y_train)
y_pred_xgb = xgb_classifier.predict(X_test_scaled)

print("\nXGBoost Classifier:")
print("Accuracy:", accuracy_score(y_test, y_pred_xgb))
print(classification_report(y_test, y_pred_xgb))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_xgb))
# Out:
# Random Forest Classifier:
# Accuracy: 0.36585365853658536
#               precision    recall  f1-score   support
#
#            0       0.42      0.41      0.41       729
#            1       0.35      0.29      0.32       769
#            2       0.33      0.26      0.29       750
#            3       0.33      0.35      0.34       709
#            4       0.39      0.53      0.45       774
#
#     accuracy                           0.37      3731
#    macro avg       0.36      0.37      0.36      3731
# weighted avg       0.36      0.37      0.36      3731
#
# Confusion Matrix:
#  [[297 131  80  93 128]
#  [145 220 130 128 146]
#  [109 111 195 142 193]
#  [ 75 107 101 246 180]
#  [ 82  55  88 142 407]]
# C:\Users\macie\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [21:25:47] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "learning", "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# ...

# %%
# !pip install optuna
# Out:
# ...
#    ---------------------------------------- 0.0/383.6 kB ? eta -:--:--
#    --- ------------------------------------ 30.7/383.6 kB ? eta -:--:--
#    ------ --------------------------------- 61.4/383.6 kB 1.1 MB/s eta 0:00:01
#    ----------- -------------------------- 112.6/383.6 kB 939.4 kB/s eta 0:00:01
#    ------------------ --------------------- 174.1/383.6 kB 1.1 MB/s eta 0:00:01
#    -------------------- ------------------- 194.6/383.6 kB 1.1 MB/s eta 0:00:01
#    ---------------------- --------------- 225.3/383.6 kB 860.2 kB/s eta 0:00:01
#    ----------------------- -------------- 235.5/383.6 kB 850.1 kB/s eta 0:00:01
#    ----------------------- -------------- 235.5/383.6 kB 850.1 kB/s eta 0:00:01
#    ----------------------- -------------- 235.5/383.6 kB 850.1 kB/s eta 0:00:01
#    --------------------------- ---------- 276.5/383.6 kB 655.8 kB/s eta 0:00:01
#    --------------------------- ---------- 276.5/383.6 kB 655.8 kB/s eta 0:00:01
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
import optuna
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Feature Engineering - nowe cechy
# if 'Likes' in dane_clean.columns and 'Comments' in dane_clean.columns:
#     dane_clean['likes_per_comment'] = dane_clean['Likes'] / (dane_clean['Comments'] + 1)
# if 'Stream' in dane_clean.columns and 'Duration_ms' in dane_clean.columns:
#     dane_clean['stream_per_ms'] = dane_clean['Stream'] / (dane_clean['Duration_ms'] + 1)
    

# Korelacja Pearsona - analiza zależności liniowych
correlation_matrix_pearson = df.corr(method='pearson')
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix_pearson, annot=True, fmt=".2f", cmap='coolwarm')
plt.title("Korelacja Pearsona - cechy numeryczne")
plt.show()

# %%
correlation_matrix_spearman = df.corr(method='spearman')
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix_pearson, annot=True, fmt=".2f", cmap='viridis')
plt.title("Korelacja Spearmana - cechy numeryczne")
plt.show()

# %%
# Wybór cech numerycznych + encoding dla ewentualnych cech kategorycznych
features = df.drop(columns=['Views', 'popularity_class'])
target = df['popularity_class'].astype(int)

categorical_cols = features.select_dtypes(include=['object', 'category']).columns.tolist()
numerical_cols = features.select_dtypes(include=['int64', 'float64']).columns.tolist()

preprocessor = ColumnTransformer([
    ('num', StandardScaler(), numerical_cols),
    ('cat', OneHotEncoder(handle_unknown='ignore'),categorical_cols)
])

X_processed = preprocessor.fit_transform(features)

# Wybór najlepszych cech statystycznie (ANOVA)
selector = SelectKBest(score_func=f_classif, k='all')
selector.fit(X_processed, target)
scores = selector.scores_

feature_names = preprocessor.get_feature_names_out()

anova_df = pd.DataFrame({"Feature": feature_names, "F-Score": scores})
anova_df = anova_df.sort_values(by="F-Score", ascending=False)

plt.figure(figsize=(14,8))
sns.barplot(data=anova_df.head(30), x="F-Score", y="Feature", palette="mako")
plt.title("Top 30 cech wg testu ANOVA (F-score)")
plt.xlabel("F-Score")
plt.ylabel("Cecha")
plt.tight_layout()
plt.show()

# %%
X_selected = selector.transform(X_processed)
X_train, X_test, y_train, y_test = train_test_split(X_selected, target, test_size=0.2, random_state=42)

# Optymalizacja Hiperparametrów + trening modelu (XGBoost)
def objective(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 50, 300),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
    }
    model = XGBClassifier(
        **params,
        use_label_encoder=False,
        eval_metric='mlogloss',
        random_state=42
    )
    model.fit(X_train, y_train)
    preds = model.predict(X_test)
    return accuracy_score(y_test, preds)

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=30)

best_params = study.best_trial.params
print("\nNajlepsze parametry:", best_params)

final_model = XGBClassifier(**best_params, use_label_encoder=False, eval_metric='mlogloss', random_state=42)
final_model.fit(X_train, y_train)
y_pred = final_model.predict(X_test)

print("\nRaport końcowy:")
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [I 2025-04-01 21:41:49,874] A new study created in memory with name: no-name-cbfe74e0-d433-42de-9f46-6272bc3efb89
# C:\Users\macie\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [21:41:49] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-04-01 21:41:52,743] Trial 0 finished with value: 0.34065934065934067 and parameters: {'n_estimators': 209, 'max_depth': 10, 'learning_rate': 0.29617386136653373, 'subsample': 0.8717283010386998, 'colsample_bytree': 0.6631083775336477}. Best is trial 0 with value: 0.34065934065934067.
# C:\Users\macie\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [21:41:52] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18652 entries, 0 to 20717
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Danceability      18652 non-null  float64
#  1   Energy            18652 non-null  float64
#  2   Loudness          18652 non-null  float64
#  3   Speechiness       18652 non-null  float64
#  4   Acousticness      18652 non-null  float64
#  5   Instrumentalness  18652 non-null  float64
#  6   Liveness          18652 non-null  float64
#  7   Valence           18652 non-null  float64
#  8   Tempo             18652 non-null  float64
#  9   Duration_ms       18652 non-null  float64
#  10  Views             18652 non-null  float64
#  11  popularity_class  18652 non-null  category
# dtypes: category(1), float64(11)
# memory usage: 1.7 MB

# %%
import scipy.stats as stats

spearman_tests = {col: stats.spearmanr(df[col], df["Views"])[1] for col in df.columns if col != "Views"}
spearman_tests
# Out:
# {'Danceability': 1.095894221417582e-36,
#  'Energy': 1.2955380775240963e-27,
#  'Loudness': 2.1323245559330312e-127,
#  'Speechiness': 0.041198672102829174,
#  'Acousticness': 9.167842444469016e-43,
#  'Instrumentalness': 2.967311584397711e-107,
#  'Liveness': 0.20012582707416385,
#  'Valence': 7.931223694354118e-06,
#  'Tempo': 0.0059566591582333895,
#  'Duration_ms': 2.9873942371014252e-68,
#  'popularity_class': 0.0}
